# %%
# %run /Users/denis/Documents/Projects/scripts/init.ipy
os.chdir('../..')
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.

# %% [markdown]
# ### Infiles

# %%
infile = '../rawdata/gcp/LINCS_GCP_Plate35_annotated_minimized_2016-06-09_13-14-47.gct'

# %% [markdown]
# ### Computation

# %%
# Parse
gctFile = parse(infile)

# Get data
gcp_dataframe = gctFile.data_df

# Rename 
gcp_dataframe = gcp_dataframe.rename(index=gctFile.row_metadata_df.to_dict()['pr_gcp_histone_mark']).drop('H3NORM(41-49)')

# %%
gcp_dataframe.head()
# Out:
# cid      GMA-2E708-001A01  GMA-2E708-002A02  GMA-2E708-003A03  \
# rid
# H3K4me0          1.390007          1.371392          1.479748
# H3K4me1          1.076491          1.156914          1.130931
# H3K4me2          0.858777          0.927517          1.007339
# H3K4me3         -0.063258          0.137110          0.209765
# H3K4ac1         -1.501034         -1.372954         -1.347766
#
# cid      GMA-2E708-004A04  GMA-2E708-005A05  GMA-2E708-006A06  \
# rid
# H3K4me0          0.021906          0.132906         -1.032684
# H3K4me1          1.245982          1.255199         -0.231583
# H3K4me2          0.522759          0.961327         -0.529281
# H3K4me3         -0.738168         -0.128945         -1.590745
# H3K4ac1         -1.400492         -1.028852         -2.582944
#
# cid      GMA-2E708-007A07  GMA-2E708-008A08  GMA-2E708-009A09  \
# rid
# H3K4me0         -1.071270         -0.463947         -0.869860
# H3K4me1         -0.175436          0.221197         -0.488836
# ...

# %%
gctFile.row_metadata_df.pr_gcp_histone_mark.value_counts()
# Out:
# H3NORM(41-49)          2
# H3K9me2K14ac1          1
# H3K18ac1K23ac1         1
# H3K27me2K36me0         1
# H3K4me0                1
# H3K79me0               1
# H3K4me1                1
# H3K9me2S10ph1K14ac0    1
# H3K9me2S10ph1K14ac1    1
# H3K4me2                1
# H3K4me3                1
# H3K9me1K14ac1          1
# H3K18ac0K23ac0         1
# H3K9me0S10ph1K14ac0    1
# H3K9me0S10ph1K14ac1    1
# H3K27me1K36me1         1
# H3K27me1K36me0         1
# H3K27me1K36me3         1
# H3K27me1K36me2         1
# H3K56me0               1
# H3K56me1               1
# H3K56me2               1
# H3K4ac1                1
# H3K9ac1S10ph1K14ac1    1
# H3K9ac1S10ph1K14ac0    1
# H3K27ac1K36me1         1
# H3K27ac1K36me0         1
# H3K9me3K14ac0          1
# H3K9me3K14ac1          1
# H3K27me2K36me3         1
# H3K9me1S10ph1K14ac0    1
# H3K9me2K14ac0          1
# H3K9me1S10ph1K14ac1    1
# H3K9me0K14ac1          1
# H3.3K27me0K36me0       1
# H3K9me3S10ph1K14ac1    1
# H3K9me3S10ph1K14ac0    1
# ...
